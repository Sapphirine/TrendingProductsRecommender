# %%
import os
import findspark
os.environ['PYSPARK_SUBMIT_ARGS'] = (
    "--repositories http://repo.hortonworks.com/content/groups/public/ "
    "--packages com.hortonworks:shc-core:1.1.1-2.1-s_2.11 "
    " pyspark-shell")
findspark.init()
from pyspark import SparkContext
from pyspark.sql import SQLContext
import json

# %%
sc = SparkContext()
sqlc = SQLContext(sc)

# %%
data_source_format = 'org.apache.spark.sql.execution.datasources.hbase'
TABLE = "20181210_224422_alexdziena_tweets"

# %%
catalog = json.dumps({
    "table":{"namespace":"default", "name":TABLE},
    "rowkey":"row_id",
    "columns":{
        "row_id":{"cf":"rowkey", "col":"row_id", "type":"string"},
        "category":{"cf":"tweet", "col":"category", "type":"string"},
        "contributors":{"cf":"tweet", "col":"contributors", "type":"string"},
        "coordinates":{"cf":"tweet", "col":"coordinates", "type":"string"},
        "created_at":{"cf":"tweet", "col":"created_at", "type":"string"},
        "display_text_range":{"cf":"tweet", "col":"display_text_range", "type":"string"},
        "entities":{"cf":"tweet", "col":"entities", "type":"string"},
        "extended_tweet":{"cf":"tweet", "col":"extended_tweet", "type":"string"},
        "favorite_count":{"cf":"tweet", "col":"favorite_count", "type":"bigint"},
        "favorited":{"cf":"tweet", "col":"favorited", "type":"boolean"},
        "filter_level":{"cf":"tweet", "col":"filter_level", "type":"string"},
        "geo":{"cf":"tweet", "col":"geo", "type":"string"},
        "id":{"cf":"tweet", "col":"id", "type":"bigint"},
        "in_reply_to_screen_name":{"cf":"tweet", "col":"in_reply_to_screen_name", "type":"string"},
        "in_reply_to_status_id":{"cf":"tweet", "col":"in_reply_to_status_id", "type":"string"},
        "in_reply_to_status_id_str":{"cf":"tweet", "col":"in_reply_to_status_id_str", "type":"string"},
        "in_reply_to_user_id":{"cf":"tweet", "col":"in_reply_to_user_id", "type":"string"},
        "in_reply_to_user_id_str":{"cf":"tweet", "col":"in_reply_to_user_id_str", "type":"string"},
        "is_quote_status":{"cf":"tweet", "col":"is_quote_status", "type":"boolean"},
        "lang":{"cf":"tweet", "col":"lang", "type":"string"},
        "place":{"cf":"tweet", "col":"place", "type":"string"},
        "quote_count":{"cf":"tweet", "col":"quote_count", "type":"bigint"},
        "reply_count":{"cf":"tweet", "col":"reply_count", "type":"bigint"},
        "retweet_count":{"cf":"tweet", "col":"retweet_count", "type":"bigint"},
        "retweeted":{"cf":"tweet", "col":"retweeted", "type":"boolean"},
        "source":{"cf":"tweet", "col":"source", "type":"string"},
        "text":{"cf":"tweet", "col":"text", "type":"string"},
        "timestamp_ms":{"cf":"tweet", "col":"timestamp_ms", "type":"bigint"},
        "truncated":{"cf":"tweet", "col":"truncated", "type":"boolean"},
        "sentiment":{"cf":"tweet", "col":"sentiment", "type":"boolean"},
        "product":{"cf":"tweet", "col":"product", "type":"string"},
    }
})


# Writing
#df.write\
#.options(catalog=catalog)\  # alternatively: .option('catalog', catalog)
#.format(data_source_format)\
#.save()

# Reading
df = sqlc.read\
.options(catalog=catalog)\
.format(data_source_format)\
.load()

# %%
# df.selectExpr(
#     "product"
# ).groupBy("product").count().toJSON().collect()
testing_counts = ['{"product":"Logitech Speaker for iPod and iPhone","count":193}',
 '{"product":"Cheetah Mounts APDAM3B Dual Articulating Arm TV Wall Mount Bracket for 20-65” TVs up to VESA 400 and 115lbs, Mounts to Two 16\\" studs and includes a Twisted Veins 10’ HDMI Cable and a 6” 3-Axis Magnetic Bubble Level","count":8001}',
 '{"product":"Halo 4","count":3123}',
 '{"product":"Syma S107/S107G R/C Helicopter *Colors Vary","count":51}',
 '{"product":"VTech Sit-to-Stand Learning Walker","count":63}',
 '{"product":"Mediabridge - 3.5mm Male To (2) RCA Stereo Audio Cable- Step Down Design accommodates iPhone, iTouch, SmartPhones & MP3 cases","count":1157}',
 '{"product":"Sennheiser Headphones","count":3665}',
 '{"product":"Final Fantasy X","count":3330}',
 '{"product":"The Original Stomp Rocket","count":191}',
 '{"product":"Mass Effect 2","count":80}',
 '{"product":"Grove Square Cappuccino, Single Serve Cup for Keurig K-Cup Brewers","count":430}',
 '{"product":"Sanyo NEW 1500 eneloop AA Ni-MH Pre-Charged Rechargeable Batteries","count":4348}',
 '{"product":"Omicron TURENO HDTV Speaker subwoofer","count":329}',
 '{"product":"Cards Against Humanity","count":870}',
 '{"product":"Grand Theft Auto V","count":755}',
 '{"product":"LeapFrog Learn & Groove8482; Musical Table","count":205}',
 '{"product":"Keurig, The Original Donut Shop, K-Cup packs","count":371}',
 '{"product":"Fisher-Price Ocean Wonders Aquarium Cradle Swing","count":97}',
 '{"product":"Call of Duty: Black Ops II","count":36475}',
 '{"product":"HDMI-DVI Cables","count":4962}',
 '{"product":"BioShock Infinite","count":2154}',
 '{"product":"Timothy\'s World Coffee K-Cup Portion Pack for Keurig K-Cup Brewers","count":362}',
 '{"product":"PlayStation 4 500GB Console [Old Model]","count":77197}',
 '{"product":"Call of Duty 4: Modern Warfare","count":1296}',
 '{"product":"Davidson\'s Tea Bulk","count":20}',
 '{"product":"Syma S107/S107G  R/C Helicopter with Gyro","count":273}',
 '{"product":"Tuscan Dairy Whole Vitamin D Milk, Gallon, 128 oz","count":1908}',
 '{"product":"San Francisco Bay One Cup","count":14}',
 '{"product":"JLab JBuds Hi-Fi Noise-Reducing Ear Buds (Purple)","count":138}',
 '{"product":"Keurig Green Mountain Coffee K-Cup Packs","count":3}',
 '{"product":"Snap Circuits Jr. SC-100","count":64}',
 '{"product":"Grand Theft Auto IV","count":6053}',
 '{"product":"66 AUDIO - BTS+ SPORT - Bluetooth Wireless Headphones - 25+ Hour Battery, Voice Call Noise Cancellation, Stereo Sound","count":1592}',
 '{"product":"Electrohome EAAC601 Projection Alarm Clock with AM/FM Radio, Battery Backup, Auto Time Set, Dual Alarm, Nap/Sleep Timer, Indoor Temperature/Day/Date Display with Dimming, 3.5mm Audio Connection","count":8619}',
 '{"product":"Destiny","count":5270}',
 '{"product":"Fisher-Price Ocean Wonders Soothe and Glow Seahorse","count":1243}',
 '{"product":"Brooklyn Beans Single-cup Coffee for Keurig K-Cup Brewers, 40-Count","count":4}',
 '{"product":"Spot It!","count":7}',
 '{"product":"Celestial Seasonings Tea","count":20}',
 '{"product":"Nutiva Organic Virgin Coconut Oil, 15 Ounce","count":197}']
ret = {}
for count in testing_counts:
    j = json.loads(count)
    ret[j['product']] = j['count']
print(ret)
# Out:
# {'Logitech Speaker for iPod and iPhone': 193, 'Cheetah Mounts APDAM3B Dual Articulating Arm TV Wall Mount Bracket for 20-65” TVs up to VESA 400 and 115lbs, Mounts to Two 16" studs and includes a Twisted Veins 10’ HDMI Cable and a 6” 3-Axis Magnetic Bubble Level': 8001, 'Halo 4': 3123, 'Syma S107/S107G R/C Helicopter *Colors Vary': 51, 'VTech Sit-to-Stand Learning Walker': 63, 'Mediabridge - 3.5mm Male To (2) RCA Stereo Audio Cable- Step Down Design accommodates iPhone, iTouch, SmartPhones & MP3 cases': 1157, 'Sennheiser Headphones': 3665, 'Final Fantasy X': 3330, 'The Original Stomp Rocket': 191, 'Mass Effect 2': 80, 'Grove Square Cappuccino, Single Serve Cup for Keurig K-Cup Brewers': 430, 'Sanyo NEW 1500 eneloop AA Ni-MH Pre-Charged Rechargeable Batteries': 4348, 'Omicron TURENO HDTV Speaker subwoofer': 329, 'Cards Against Humanity': 870, 'Grand Theft Auto V': 755, 'LeapFrog Learn & Groove8482; Musical Table': 205, 'Keurig, The Original Donut Shop, K-Cup packs': 371, 'Fisher-Price 
# ...

# %%
df.groupBy('product').count().toJSON().collect()
# Out:
# ['{"product":"Logitech Speaker for iPod and iPhone","count":193}',
#  '{"product":"Cheetah Mounts APDAM3B Dual Articulating Arm TV Wall Mount Bracket for 20-65” TVs up to VESA 400 and 115lbs, Mounts to Two 16\\" studs and includes a Twisted Veins 10’ HDMI Cable and a 6” 3-Axis Magnetic Bubble Level","count":8001}',
#  '{"product":"Halo 4","count":3123}',
#  '{"product":"Syma S107/S107G R/C Helicopter *Colors Vary","count":51}',
#  '{"product":"VTech Sit-to-Stand Learning Walker","count":63}',
#  '{"product":"Mediabridge - 3.5mm Male To (2) RCA Stereo Audio Cable- Step Down Design accommodates iPhone, iTouch, SmartPhones & MP3 cases","count":1157}',
#  '{"product":"Sennheiser Headphones","count":3665}',
#  '{"product":"Final Fantasy X","count":3330}',
#  '{"product":"The Original Stomp Rocket","count":191}',
#  '{"product":"Mass Effect 2","count":80}',
#  '{"product":"Grove Square Cappuccino, Single Serve Cup for Keurig K-Cup Brewers","count":430}',
# ...

# %%
df.printSchema()

# %%
df.count()

# %%
from pyspark.sql.functions import when, col, lower
df = df.withColumn('launch_xbox', lower(col('text')).like("%launch%xbox%"))

# %%
import pyspark.sql.functions as f
import itertools
import json
import re
ret = {}
terms = {
  "general": [
    "launch",
    "trending",
    "preorder",
    "expo",
    "release",
    "love"
  ],
  "video_games": [
    "E3",
    "Switch",
    "Playstation",
    "PS4",
    "Xbox",
    "\"PC game\"",
    "\"Video game\"",
    "game",
    "gaming",
    "Bethesda",
    "Nintendo",
    "Blizzard game"
  ],
  "toys": [
    "Lego",
    "\"Action Figure\"",
    "\"Melissa & Doug\"",
    "\"Melissa and Doug\"",
    "Crayola",
    "Barbie",
    "\"Little tikes\"",
    "Fisher-price",
    "\"Fisher price\"",
    "Fisherprice",
    "Disney toy",
    "K'nex",
    "Knex",
    "Glitter Girls doll",
    "FurReal friends",
    "PlayDoh",
    "Play-Doh",
    "\"Play Doh\""
  ],
  "snacks": [
    "\"Cheetos\"",
    "\"Combos\"",
    "\"CornNuts\"",
    "\"Doritos\"",
    "Haribo",
    "\"Jack Link's\"",
    "\"Keebler\"",
    "\"Kettle chips\"",
    "\"KIND Healthy Snacks\"",
    "\"Lay's\"",
    "\"LesserEvil\"",
    "\"Little Debbie\"",
    "\"Oreos\"",
    "\"Pringles\"",
    "\"Pirate's Booty\"",
    "\"Popchips\"",
    "\"Reese's\"",
    "\"Ruffles\"",
    "\"Tostitos\"",
    "\"Utz\"",
    "\"Zapp's\"",
    "delicious chips"
  ],
  "electronics": [
    "Blueray player",
    "\"Smart home\"",
    "\"Laptop\"",
    "Apple",
    "Microsoft",
    "Samsung",
    "Philips",
    "Sony",
    "Panasonic",
    "Dell",
    "Toshiba"
  ]

}
col_names = []
like_exprs = []
df2 = df
counts = []
prog = re.compile(r'"(.*)"')

where_filter = ('sentiment = True and (favorite_count > 0 or retweet_count > 0 or quote_count > 0 or reply_count > 0)')
for category in terms:
    if category != 'general':
        cat_terms = terms[category]
        if cat_terms:
            for term in cat_terms:
                match = prog.match(term)
                if match:
                    print(match.groups())
                    like_expr = '%' + '%'.join(match.groups()).lower() + '%'
                else:
                    like_expr = '%' + term.lower().replace('%', '\%').replace(' ', '%').replace('"', '') + '%'
                like_exprs.append(like_expr)
                col_name = term.lower().replace('%', '\%').replace(' ', '_').replace('"', '')
    #             print(col_name)
    #             print(like_expr)
                df2 = df2.withColumn(col_name, lower(col('text')).like(like_expr))
                col_names.append(col_name)
                counts.append(
                    f.sum(f.when(f.col(col_name), 1)).alias(col_name)
                )
#             ret[col_name] = df.filter(where_filter).filter(col(col_name) == True).count()
# print(like_exprs)
# print(col_names)
print(df2.schema)
result = json.loads(df2.filter(where_filter).select(counts).toJSON().collect()[0])

print(result)

# %%
df.selectExpr(
    "row_id",
#     "contributors",
#     "geo",
#     "created_at",
    "category",
    "text",
#     "favorite_count",
    "reply_count",
    "retweet_count",
    "quote_count",
    "retweeted",
#     "sentiment",
#     "launch_xbox"
).where("favorite_count > 0 and sentiment = True and launch_xbox = True").show(10)

# %% [markdown]
# # Visually explore the result

# %%
from pyspark.sql.functions import avg
display(dfsummed.select("category","favorite_count").groupBy("category").agg(avg("favorite_count")))

# %% [markdown]
# #Convert Spark Dataframe into Panda to use matplotlib

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd_df = (df.selectExpr(
    "row_id",
#     "contributors",
#     "geo",
#     "created_at",
    "category",
    "text",
    "favorite_count",
    "reply_count",
    "retweet_count",
    "quote_count",
    "retweeted"
).where("favorite_count > 0 and retweet_count > 0 and category = 'snacks'")).toPandas()

#plt.show(display(df.select("category","favorite_count").groupBy("category").agg(avg("favorite_count"))))

# %%
pd_df.to_csv("20181210_224422_alexdziena_tweets.csv")

# %%
ax = plt.gca()

pd_df.plot(kind="line", x="category",y="favorite_count",ax=ax)
pd_df.plot(kind="line", x="category",y="retweet_count", color="blue",ax=ax)

#plt.show()

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

men_means, men_std = (20, 35, 30, 35, 27), (2, 3, 4, 1, 2)
women_means, women_std = (25, 32, 34, 20, 25), (3, 5, 2, 3, 3)

ind = np.arange(len(men_means))  # the x locations for the groups
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, men_means, width, yerr=men_std,
                color='SkyBlue', label='Men')
rects2 = ax.bar(ind + width/2, women_means, width, yerr=women_std,
                color='IndianRed', label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
ax.legend()


def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(height), ha=ha[xpos], va='bottom')


autolabel(rects1, "left")
autolabel(rects2, "right")

plt.show()
